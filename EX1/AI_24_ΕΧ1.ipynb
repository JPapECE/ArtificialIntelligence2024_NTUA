# %% [markdown]
# # Τεχνητή Νοημοσύνη: Ενότητα 1
#
#
#
# ---
#
#
#
# Ο στόχος της εργασίας είναι η εφαρμογή αλγορίθμων αναζήτησης και εύρεσης καλύτερου μονοπατιού σε λαβύρινθο διαστάσεων $N\times N$

# %% [markdown]
# ``` Νικόλαος Μωραΐτης ΑΜ 03121172 ```
#
#
# ```Δημήτριος Παπαδεράκης ΑΜ 03121205 ```

# %% [markdown]
# # Εκφώνηση
#
# ## Μέρος 1
# Ο στόχος του πρώτου μέρους είναι η κατασκευή **λαβυρίνθων**. [Σε αυτό το άρθρο της Wikipedia](https://en.wikipedia.org/wiki/Maze_generation_algorithm) μπορείτε να βρείτε διάφορους αλγορίθμους για αυτό το σκοπό, συμπεριλαμβανομένου κι αυτού που χρησιμοποιείται παρακάτω. Προσέξτε ότι οι αλγόριθμοι του παραπάνω άρθρου κατασκευάζουν ένα μόνο μονοπάτι από κάθε σημείο του λαβυρίνθου προς οποιοδήποτε άλλο (η δομή του λαβυρίνθου έχει μορφή συνεκτικού δέντρου). Καλείστε να συμπληρώσετε τον κώδικα στα σημεία που λείπει ώστε οι λαβύρινθοι που κατασκευάζει τυχαία να έχουν μεταβλητή πυκνότητα εμποδίων/τοίχων (καθορίζεται από την παράμετρο threshold). Όλοι οι χάρτες θα πρέπει να έχουν τουλάχιστον ένα μονοπάτι μεταξύ ενός σημείου αφετηρίας (S) και ενός σημείου τερματισμού (F).
#
# Σε όλα τα ερωτήματα φροντίστε να χρησιμοποιήσετε **δομημένο** κώδικα, με **σχόλια** που επισημαίνουν τη λογική του.
#
#
# ### Παραδείγματα λαβυρίνθων
# ![index1.png](data:image/png;base64,...)
# ![index2.png](data:image/png;base64,...)
# ![index3.png](data:image/png;base64,...)

# %% [markdown]
# ## Μέρος 2
#
# Στο δεύτερο μέρος της εργασίας καλείστε να υλοποιήσετε διάφορους αλγορίθμους εύρεσης συντομότερων μονοπατιών μεταξύ δυο κόμβων για τους λαβυρίνθους που παράγονται από τον κώδικα του πρώτου μέρους. Παράλληλα καλείστε να κατασκευάσετε και διάφορες συναρτήσεις κόστους τόσο για την μέτρηση των πραγματικών αποστάσεων όσο και για την εκτίμηση των αποστάσεων από έναν κόμβο στον κόμβο στόχο (heuristic). Επίσης μπορείτε να πειραματιστείτε με οποιαδήποτε από τις παραμέτρους κάθε αλγορίθμου με σκοπό να μελετήσετε το πώς οι αλλαγές αυτές επηρεάζουν την πολυπλοκότητα, τον χρόνο καθώς και βέλτιστο μονοπάτι. Οι παραπάνω αλγόριθμοι καθώς και οι παραλλαγές τους θα τρέξουν σε λαβυρίνθους με διαφορετικά μεγέθη. Υλοποιήστε τους αλγορίθμους στο κελί κώδικα του Μέρους 2.<br>
#
# Η γενική μορφή της συνάρτησης κόστους στον αλγόριθμο Α* είναι:
# $$f(n)=g(n)+h(n)$$
# Παραπάνω, η συνάρτηση $g(n)$ δίνει την πραγματική απόσταση από το σημείο εκκίνησης μέχρι τον κόμβο $n$, και η συνάρτηση $h(n)$ αποτελεί μια ευριστική της απόστασης από τον κόμβο $n$ μέχρι τον στόχο. Σας ζητείται να πειραματιστείτε με τις εξής επιλογές για τις δύο συναρτήσεις:
# * $g(n)=0$ και $h(n)=\{\text{manhattan}(n),\text{euclidean}(n)\}$. Ποιος αλγόριθμος αναζήτησης προκύπτει; Μπορεί να βρει πάντα το βέλτιστο μονοπάτι;
# * $g(n)=1$ και $h(n)=0$. Ποιος αλγόριθμος αναζήτησης προκύπτει; Μπορεί να βρει πάντα το βέλτιστο μονοπάτι;
# * $g(n)=1$ και $h(n)=\{\text{manhattan}(n),\text{euclidean}(n)\}$. Ποιος αλγόριθμος αναζήτησης προκύπτει; Μπορεί να βρει πάντα το βέλτιστο μονοπάτι;
#
# Μπορείτε να προτείνετε και άλλες ευριστικές συναρτήσεις εκτός από τις αποστάσεις manhattan και euclidean;

# %% [markdown]
# ## Μέρος 3
#
# Στο τρίτο μέρος καλείστε να υλοποιήσετε μια συγκριτική μελέτη των αλγορίθμων που κατασκευάσατε στο Μέρος 2 με σκοπό να καταλήξετε σε ορισμένα συμπεράσματα. Οι αλγόριθμοι θα συγκρίνονται με βάση την πολυπλοκότητά τους και το κατά πόσο μπορούν να βρούν το βέλτιστο μονοπάτι.
#
# Για να κρίνουμε τον τρόπο με τον οποίο το μέγεθος του λαβύρινθου επηρεάζει τους αλγορίθμους, κατασκευάζουμε χάρτες με διάσταση $N=[10,20,\ldots,100]$. Για κάθε παραμετροποίηση προτείνεται να κατασκευάζετε 100 διαφορετικούς χάρτες, στους οποίους θα εκτελείτε τους παραπάνω αλγορίθμους.
#
# Έπειτα, ζητείται να συλλέξετε τα εξής χαρακτηριστικά:
#  * το μήκος του ελάχιστου μονοπατιού που εξάγει ο εκάστοτε αλγόριθμος.
#  * το πλήθος των επεκτεταμένων κόμβων (expanded nodes) του κάθε αλγορίθμου, που αποτελεί μέτρο της πολυπλοκότητάς του.
#
#  Για να σας είναι εύκολο να εξάγετε συμπεράσματα από τις παραπάνω παραμετροποιήσεις, ζητείται να κατασκευάσετε δύο γραφικές παραστάσεις:
#  * το μήκος του ελάχιστου μονοπατιού συναρτήσει του μεγέθους του χάρτη
#  * το πλήθος των expanded nodes συναρτήσει του μεγέθους του χάρτη
#
#
#
#  Σας ζητείται σχολιάσετε τις παραπάνω γραφικές παραστάσεις, και συγκεκριμένα το πώς μεταβάλλεται η συμπεριφορά των αλγορίθμων συναρτήσει του $N$.
#
#  Σημειώνουμε τα παρακάτω:
#
#  * Σε όλα τα παραπάνω πειράματα μπορείτε να λάβετε σαν σημείο εκκίνησης το $(1,1)$ και σαν σημείο τερματισμού το $(N-2,N-2)$. Εναλλακτικά, μπορείτε να πειραματισθείτε με τυχαία σημεία εκκινησης και τερματισμού.
#  * Αν και οι χάρτες παράγονται τυχαία, η εκτέλεση αλγορίθμων σε διαφορετικούς χάρτες παράγει μη συγκρίσιμα αποτελέσματα.
#  * Για λόγους ευκολίας σύγκρισης, προτείνεται να τοποθετήσετε πολλαπλές γραφικές παραστάσεις στο ίδιο σύστημα αξόνων, όπου αυτό είναι εφικτό.
#
# **Visualization**: Παράλληλα με τα παραπάνω σάς δίνεται έτοιμη και μια κλάση η όποια κατασκευάζει ένα animation της αναζήτησης το οποίο υλοποιεί κάθε αλγόριθμος. Για την χρήση της κλάσης αυτής πρέπει να κάνετε τα εξής 4 βήματα:
#
# 1.	Δημιουργία ενός instance της κλάσης εκτελώντας την παρακάτω εντολή: `visualization(Start, Goal)`. Η εντολή αυτή δημιουργεί ένα αντικείμενο τύπου visualization.
#
# 2.	Το βίντεο που παράγεται κάθε φορά ουσιαστικά αποτελείται από stacked frames. Συνεπώς σε κάθε βήμα εκτέλεσης όπου δηλαδή θέλουμε να προσθέσουμε ένα frame στο βίντεο πρέπει να καλέσουμε την μέθοδο της κλάσης: `draw_step(grid, frontier, expanded_nodes)` όπου το πρώτο όρισμα είναι ένας χάρτης (τύπου Maze) το δεύτερο μια λίστα με το μέτωπο της αναζήτηση ενώ το τρίτο μια λίστα με τους κόμβους οι όποιοι έχουν ήδη επεκταθεί από τον αλγόριθμο.
#
# 3.	(Προαιρετικό) Αν θέλουμε να προσθέσουμε στο animation και το βέλτιστο μονοπάτι που βρήκε ο αλγόριθμός μας μπορούμε να καλέσουμε την μέθοδο add_path(path) η οποία δέχεται σαν όρισμα μια λίστα με όλους τους κόμβους που ανήκουν στο βέλτιστο μονοπάτι (συμπεριλαμβανομένων και των κόμβων αρχής και τέλους).
#
# 4.	Τέλος καλούμε την συνάρτηση `show_gif()` η όποια εμφανίζει το animation. Επίσης μπορούμε και να αποθηκεύσουμε το gif καλώντας την συνάρτηση `save_gif (filename)` (το αρχείο πρέπει να έχει κατάληξη .gif) καθώς επίσης μπορούμε να εμφανίσουμε μόνο το τελευταίο frame καλώντας την συνάρτηση `show_last_frame()` στο όποιο (αν έχουν γίνει όλα όπως παραπάνω) θα φαίνονται όλοι οι κόμβοι οι οποίοι έχουν επεκταθεί από τον αλγόριθμο, το τελευταίο μέτωπο και (προαιρετικά) και το βέλτιστο μονοπάτι.
#
# Μπορείτε να καταλήξετε στα ίδια συμπεράσματα όσον αφορά την πολυπλοκότητα των αλγορίθμων παρατηρώντας το visualization;

# %% [markdown]
# ## Μέρος 4
#
# Στο τέταρτο μέρος της εργασίας στο λαβύρινθο υπάρχει ένα φάντασμα 👻! Ο στόχος είναι να φτάσουμε στο σημείο τερματισμού αποφεύγοντας το φάντασμα, το οποίο μας κυνηγάει τρέχοντας σε κάθε βήμα τον δικό του Α*. Ο κώδικας που τρέχει το φάντασμα ''Agent'' σας δίνεται έτοιμος.
#
# Για την αποφυγή του φαντάσματος θα υλοποιήσουμε τον αλγόριθμο ΑΒ. Συγκεκριμένα, σας δίνεται η κλάση ''ΑΒagent'' στην οποία καλείστε να συμπληρώσετε τις κινήσεις του minimizing_player (όπως διδαχθήκατε στο μάθημα), δεδομένων των αντίστοιχων κινήσεων του maximizing_player. Στα πλαίσια του αλγορίθμου αυτού θα χρειαστεί να ορίσετε μια ευριστική συνάρτηση η οποία εκτιμά το κόστος της επόμενης κατάστασης συνυπολογίζοντας την απόσταση τόσο από το στόχο και από το φάντασμα.
#
# Περιγράψτε στο κατάλληλο markdown κελί τη συλλογιστική πορεία για τις επιλογές σας όσον αφορά την ευριστική. Πώς υπολογίσατε τις αποστάσεις (με εκτίμηση/πραγματική μετρική); Αναφέρετε αναλυτικά τα αποτέλεσματα και τις παρατηρήσεις σας σχετικά με τις παραπάνω επιλογές. Μεγαλύτερη σημασία έχει ο πειραματισμός και η αναφορά των αποτελεσμάτων, όσον αφορά αφορά την ευριστική, παρά η αναζήτηση της καλύτερης συνάρτησης. Ως αποτελέσματα ζητείται να παραθέσετε: χαρακτηριστικά gifs και χρόνους εκτέλεσης. Δικαιολογείστε γιατί ο αλγόριθμός σας δουλεύει ορθά.
#
# **ΠΡΟΣΟΧΗ!** Στο 4ο μέρος οι λαβύρινθοι που θα χρησιμοποιήσετε πρέπει να είναι αραιοί ως προς τα εμπόδια. Αν τα υπάρχοντα μονοπάτια προς το στόχο είναι λίγα, θα είναι δύσκολο να ξεφύγετε από το φάντασμα ανεξαρτήτως υλοποίησης.

# %% [markdown]
# ## Μέρος 5 (bonus)
#
# Στο πέμπτο και τελευταίο μέρος της εργασίας σάς δίνεται η δυνατότητα να κατασκευάσετε λαβυρίνθους με το χέρι, ζωγραφίζοντας. Για το σκοπό αυτό σας δίνεται η συνάρτηση draw(filename='filename.png') η οποία παράγει ένα interactive grid ώστε να σχηματίσετε το λαβύρινθο. Θεωρήστε ως μαύρο το χρώμα του εμποδίου, πράσινο την αφετηρία και κόκκινο το στόχο, και πατήστε finish για να ολοκληρωθεί η εκτέλεση του τρέχοντος κελιού. Σε περίπτωση που θέλετε να παράξετε νέο λαβύρινθο, απλά ξανατρέξτε το κελί, επιλέξτε τα τετράγωνα και πατήστε finish. Κάθε εκτέλεση αποθηκεύει την εικόνα σε μορφή png σε όνομα που μπορείτε να καθορίσετε μέσω του filename (τοποθετώντας και την κατάληξη .png) κατά την κλήση της συνάρτησης.
#
# Καλείστε λοιπόν να **κατασκευάσετε** και να **σχολιάσετε** τους παρακάτω 5 λαβυρίνθους, οι οποίοι θα ικανοποιούν τις παρακάτω συνθήκες:
#
#
# *   **Λαβύρινθος 1**: Ο Hill-climbing δεν βρίσκει μονοπάτι από την αφετηρία στο στόχο.
# *   **Λαβύρινθος 2**: Ο Α* αργεί όσο το δυνατόν περισσότερο να βρει το βέλτιστο μονοπάτι ανεξαρτήτως της μετρικής απόστασης που χρησιμοποιείται ως ευριστική. Σε τι είδους μονοπάτι η επιλογή διαφορετικής μετρικής απόστασης (Ευκλίδεια/Manhattan) ως ευριστικής οδηγεί τον Α* να βρίσκει το μονοπάτι πιο γρήγορα;
# *   **Λαβύρινθος 3**: Ο αλγόριθμος άπληστης αναζήτησης πρώτα στο καλύτερο (greedy best first) αργεί σημαντικά περισσότερο από τον Α* για να καταλήξει στο στόχο. Σε ποια περίπτωση οι δύο αλγόριθμοι θα συμπεριφέρονταν με τον ίδιο τρόπο;
# *   **Λαβύρινθος 4**: Ο Α* καταφέρνει να βρει το μονοπάτι προς το στόχο σημαντικά πιο γρήγορα από τον Dijkstra. Ο χώρος πρέπει αναγκαστικά να περιέχει εμπόδια. Πώς επηρεάζει το μέγεθος/είδος του εμποδίου τον αριθμό βημάτων που χρειάζεται ο Dijsktra και πώς τον αριθμό βημάτων του Α*;
# *   **Λαβύρινθος 5**: Ο Α* και ο Dijkstra φτάνουν στο στόχο πραγματοποιώντας τον ίδιο ακριβώς αριθμό βημάτων για την προσέγγιση της βέλτιστης διαδρομής. Σημείωση: **αγνοήστε** την τετριμμένη περίπτωση όπου ο Α* συμπεριφέρεται όπως ο Dijkstra (h(n)=0).
#
#
# Ο Α* σε όλες τις περιπτώσεις πραγματοποιεί τη βέλτιστη δυνατή αναζήτηση.
#
#
# Για κάθε λαβύρινθο που σχηματίζετε, δώστε μια σύντομη εξήγηση για την επιλογή σας.
#
# **ΠΡΟΣΟΧΗ:** το output των κελιών που σχηματίζετε διατηρείται για περιορισμένο χρονικό διάστημα στο notebook, γι αυτό καλείστε να αποθηκεύσετε τη φωτογραφία (το πραγματοποιεί η συνάρτηση draw()) και να τη μεταφέρετε στο ανάλογο markdown ώστε να μπορέσουμε να την αξιολογήσουμε.
#
#
# Στη συνέχεια, καλείστε να τρέξετε τους αλγορίθμους pathfinding πάνω στους χάρτες που σχηματίσατε. Για το σκοπό αυτό, μετά την εκτέλεση της draw() καλείτε τη συνάρτηση draw_grid() που μετατρέπει την εικόνα που σχηματίσατε σε χάρτη πάνω στον οποίο μπορούν να τρέξουν οι αλγόριθμοι με χρήση της συνάρτησης pathfinder(). Χρειάζεται να επιλέξετε κατάλληλα τα ορίσματα της pathfinder ώστε να καλέσετε το σωστό αλγόριθμο αναζήτησης σε κάθε ερώτημα. Εκτελέστε τα αντίστοιχα κελιά με τον κώδικα που σας δίνεται και παρουσιάστε την έξοδο αυτών. Φυσικά, εάν ένα ερώτημα περιλαμβάνει την εκτέλεση περισσότερων του ενός αλγορίθμου, αντιγράφετε τα αντίστοιχα κελιά για κάθε αλγόριθμο και τοποθετείτε τα σωστά ορίσματα. Τέλος, η show_gif() σάς παρουσιάζει το animation, όπως και στο Μέρος 3.
# **Παρατήρηση:** εφόσον δε σας δίνεται/δεν έχετε υλοποιήσει τον Hill climbing, δε σας ζητείται να τον τρέξετε στο χάρτη που θα σχηματίσετε.

# %% [markdown]
# ## Κώδικας visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import PillowWriter
from IPython.display import HTML

class visualization:
    def __init__(self, S, F):
        '''
          Η μέθοδος αυτή αρχικοποιεί ένα αντικείμενο τύπου visualization.
          Είσοδος:
          -> S: το σημείο εκκίνσης της αναζήτησης
          -> F: το σημείο τερματισμού
        '''
        self.S = S
        self.F = F
        self.images = []

    def draw_step(self, grid, frontier, expanded_nodes):
        '''
          Η συνάρτηση αυτή καλείται για να σχεδιαστεί ένα frame στο animation (πρακτικά έπειτα από την επέκταση κάθε κόμβου)
          Είσοδος:
          -> grid: Ένα χάρτης τύπου grid
          -> frontier: Μια λίστα με τους κόμβους που ανήκουν στο μέτωπο της αναζήτησης
          -> expanded_nodes: Μια λίστα με τους κόμβους που έχουν ήδη επεκταθεί
          Επιστρέφει: None
          Η συνάρτηση αυτή πρέπει να καλεστεί τουλάχιστον μια φορά για να μπορέσει να σχεδιαστει ένα animation (πρεπεί το animation να έχει τουλάχιστον ένα frame).
        '''
        image = np.zeros((grid.N, grid.N, 3), dtype=int)
        image[~grid.grid] = [0, 0, 0]
        image[grid.grid] = [255, 255, 255]




        for node in expanded_nodes:
            image[node] = [0, 0, 128]

        for node in frontier:
            image[node] = [0, 225, 0]

        image[self.S] = [50, 168, 64]
        image[self.F] = [168, 50, 50]
        self.images.append(image)

    def add_path(self, path):
        '''
          Η συνάρτηση αυτή προσθέτει στο τελευταίο frame το βέλτιστο μονοπάτι.
          Είσοδος:
          -> path: Μια λίστα η όποια περιέχει το βέλτιστο μονοπάτι (η οποία πρέπει να περιέχει και τον κόμβο αρχή και τον κόμβο στόχο)
          Έξοδος: None
        '''
        for n in path[1:-1]:
            image = np.copy(self.images[-1])
            image[n] = [66, 221, 245]
            self.images.append(image)
        for _ in range (100):
            self.images.append(image)

    def create_gif(self, fps = 30, repeat_delay = 2000):
        if len(self.images) == 0:
            raise EmptyStackOfImages("Error! You have to call 'draw_step' at  first.")
        fig = plt.figure()
        plt.axis('off')
        ims = []
        for img in self.images:
            img = plt.imshow(img)
            ims.append([img])
        ani = animation.ArtistAnimation(fig, ims, interval=1000//fps, blit=True, repeat_delay= repeat_delay)
        plt.close(fig)
        return ani

    def save_gif(self, filename, fps = 30):
        '''
            Η συνάρτηση αυτή ξαναδημιουργεί και αποθηκεύει το animation σε ένα αρχείο.
            Είσοδος:
            -> Το όνομα του αρχείου με κατάληξη .gif
            Έξοδος: (None)
        '''
        ani = self.create_gif(fps)
        writer = PillowWriter(fps= fps)
        ani.save(filename, writer=writer)

    def show_gif(self, fps= 30, repeat_delay = 2000):
        '''
            Η συνάρτηση αυτή εμφανίζει inline το animation.
            Είσοδος:
            -> fps: τα frames per second
            Έξοδος: Το αντικείμενο που παίζει το animation
            Exceptions: EmptyStackOfImages αν το animation δεν έχει ούτε ένα frame, δηλαδή αν η draw_step δεν έχει καλεστεί ποτέ.
        '''
        ani = self.create_gif(fps, repeat_delay)
        # return HTML(ani.to_html5_video())
        return HTML(ani.to_jshtml())

    def show_last_frame(self):
        '''
            Η μέθοδος αυτή εμφανίζει inline το τελευταίο frame που έχει δημιουργήθει.
            Είσοδος:
            Έξοδος: Το αντικείμενο που εμφανίζει την εικόνα.
            Exceptions: EmptyStackOfImages αν το animation δεν έχει ούτε ένα frame, δηλαδή αν η draw_step δεν έχει καλεστεί ποτέ.
        '''
        if len(self.images) == 0:
            raise EmptyStackOfImages("Error! You have to call 'draw_step' at  first.")
        else:
            plt.imshow(self.images[-1])


class EmptyStackOfImages(Exception):
    pass

# %% [markdown]
# # Λύση

# %% [markdown]
# ## Μέρος 1

# %%
# %matplotlib inline
import numpy as np
from queue import LifoQueue
import  random
import matplotlib.pyplot as plt


class Maze:
    def __init__(self, N, S, F, threshold=0.02):

      """
      N: integer that indicates the size of the NxN grid of the maze
      S: pair of integers that indicates the coordinates of the starting point (S)
      F: pair of integers that indicates the coordinates of the finish point (F)
      You can add any other parameters you want to customize maze creation (e.g. variables that
      control the creation of additional paths)
      """

      assert N > 2

      ## Make sure start and end are within the grid

      assert S < (N-1, N-1)
      assert F < (N-1, N-1)

      assert S > (0, 0)
      assert F > (0, 0)

      # Add here any additional constraints your implementation may have

      #assert N % 2 == 1
      #assert S[0] % 2 == 1
      #assert S[1] % 2 == 1
      #assert F[0] % 2 == 1
      #assert F[1] % 2 == 1

      self.N = N
      self.S = S
      self.F = F

      # Keep track of the agents in the Maze
      self.agents=[]

      ## Initialize grid

      self.grid = np.zeros((N, N), dtype=bool)

      def neighbors(node, N, visited, threshold):
        """
        Returns all neighbors of a node that are either unvisited, or they are visited but
        there is a wall between the node and the neighbor and the neighbor passes a random test.
        """

        l = []
        x, y = node

        # first condition in all checks is for boundaries
        # neighbors are +-2 in x or y
        # walls are +-1

        if x > 2 and (not visited[x-2, y] or (not visited[x-1,y] and random.uniform(0,1) <= threshold)):
            l.append((x-2, y))
        ### YOUR CODE HERE \/
        #we check all the neighbors , if they are unvisited we return them , else there is a small chance of returning them
        if y > 2 and (not visited[x, y-2] or (not visited[x,y-1] and random.uniform(0,1) <= threshold)):
            l.append((x, y-2))
        if x < N-2 and (not visited[x+2, y] or (not visited[x+1,y] and random.uniform(0,1) <= threshold)):
            l.append((x+2, y))
        if y < N-2 and (not visited[x, y+2] or (not visited[x,y+1] and random.uniform(0,1) <= threshold)):
            l.append((x, y+2))
        ### YOUR CODE HERE /\
        return l

      stack = []
      stack.append(self.S)
      self.grid[self.S] = True

      while stack:
          current_node = stack.pop()
          # get all unvisited neighbors (and some visited ones with a random chance)
          n = neighbors(current_node, self.N, self.grid, threshold)
          if len(n):
              stack.append(current_node)

              ### YOUR CODE HERE \/
              # select a random neighbor
              next_node = n[random.randint(0, len(n)-1)]
              ### YOUR CODE HERE /\

              ### YOUR CODE HERE \/
              x1, y1 = current_node
              x2, y2 = next_node
              # break the wall between current and next node
              self.grid[((x1+x2)//2, (y1+y2)//2)] = True
              ### YOUR CODE HERE /\

              # mark next node as visited and add it to the stack
              self.grid[next_node] = True
              stack.append(next_node)



    def adjacent_no_walls(self, node):
      x, y = node
      ret = []
      if x - 1 > -1 and self.grid[x-1,y]:
        ret.append((x-1,y))
      if x + 1 < self.N and self.grid[x+1,y]:
        ret.append((x+1,y))
      if y - 1 > -1 and self.grid[x,y-1]:
        ret.append((x,y-1))
      if y + 1 < self.N and self.grid[x,y+1]:
        ret.append((x,y+1))
      return ret



    def draw_map(self, path=None,return_image=False):
        """
        Draws the maze as an image. Considers grid values of 0/False to represent obstacles and
        values of 1/True to represent empty cells, but this can be customized. Obstacles are painted
        black and empty cells are painted white. Starting point is painted green and finish point red.
        Optionally accepts as a parameter a path within the maze which is painted blue.
        """
        image = np.zeros((self.N, self.N, 3), dtype=int)
        image[~self.grid] = [0, 0, 0]
        image[self.grid] = [255, 255, 255]


        image[self.S] = [50, 168, 64]
        image[self.F] = [168, 50, 50]
        if path:
            for n in path[1:-1]:
                image[n] = [66, 221, 245]

        if len(self.agents)>0:
          for a in self.agents:
            image[a.location]=a.color

        if return_image:
          return image
        else:
          plt.imshow(image)
          plt.xticks([])
          plt.yticks([])
          plt.show()

# %%
for N, S, F in (11, (1, 3), (7, 9)), (25, (3, 7), (23, 19)), (51, (9, 3), (41, 41)):
    map = Maze(N, S, F, threshold=2/(N*np.log(N)))#threshold aprox value equals 0.08 / 0.02 / 0.01
    map.draw_map()

# %% [markdown]
# Παρατηρούμε τους 3 λαβιρίνθους που φτιάξαμε με χρήση του αλγόριθμου *Randomized depth-first search* . Στον αλγόριθμο μας , σπάμε τον τοίχο μεταξύ ενός κόμβου και ενός τυχαία επιλεγμένου γείτονα. Αυτός ο γείτονας είτε θα είναι ένας κόμβος που δεν έχουμε ήδη επισκεφτεί , είτε θα είναι ένας που έχουμε επισκεφτεί. Η δεύτερη περίπτωση όμως συμβαίνει με πιθανότητα που εξαρτάται από την μεταβλητή **threshold**. Όσο πιο πολύ αυτή η μεταβλητή πλησιάζει το 0 τόσο πιο πυκνός από τοίχους γίνεται ο λαβύρινθος καθώς μειώνεται η πιθανότητα να διαλέξουμε γείτονα που έχουμε ήδη επισκεφτεί ,συνεπώς θα σπάσουμε λιγότερους τοίχους . Ενώ αν η συγκεκριμένη μεταβλη΄τη πλησιάσει το 1 τότε όλο και πιο αραιός θα είναι ο λαβυρινθός μας καθώς θα σπάσουμε περισσότερους τοίχους.

# %%
for N, S, F in (11, (1, 3), (7, 9)), (25, (3, 7), (23, 19)), (51, (9, 3), (41, 41)):
    map = Maze(N, S, F, threshold=20/(N*np.log(N))) #threshold aprox value equals 0.8 / 0.2 / 0.1
    map.draw_map()

# %% [markdown]
# ## Μέρος 2

# %%
from queue import PriorityQueue

class pathfinder:
    def __init__(self, S, F, grid, c, h,visualize=True):
        self.S = S
        self.F = F
        self.grid = grid
        self.cost = c
        self.heuristic = h
        self.no_expanded_nodes = 0

        #for visualization
        self.visualize=visualize
        self.vis = visualization(S, F)
        self.find_path()


    def find_path(self):
        frontier = PriorityQueue()
        frontier.put((0, self.S))
        came_from = {}
        cost_so_far = {}
        came_from[self.S] = None
        cost_so_far[self.S] = 0
        self.no_expanded_nodes = 0

        while not frontier.empty():
            current = frontier.get()[1]
            if current == self.F:
                break
            self.no_expanded_nodes += 1

            for next in  self.grid.adjacent_no_walls(current):
                ### YOUR CODE HERE \/ (cost so far+cost to next)
                new_cost = cost_so_far[current] + self.cost(current, next)
                ### YOUR CODE HERE /\

                if next not in cost_so_far or new_cost < cost_so_far[next]:
                    cost_so_far[next] = new_cost

                    ### YOUR CODE HERE \/ (c+h)
                    priority = new_cost + self.heuristic(next,self.F)
                    ### YOUR CODE HERE /\
                    frontier.put((priority, next))
                    came_from[next] = current
                #for animation
                #find frontier and expanded nodes
                restore = []
                while not frontier.empty():
                    node = frontier.get()
                    restore.append(node)
                for node in restore:
                    frontier.put(node)
                exp = []
                #find expanded nodes
                for v in came_from:
                    if v:
                        exp.append(v)
                if self.visualize:
                  self.vis.draw_step(self.grid, [r[1] for r in restore], exp)


        # follow backlinks to build path
        # current = self.F
        path = []
        while current != self.S:
            path.append(current)
            if current not in came_from:
              self.grid.draw_map()
            current = came_from[current]
        path.append(self.S)
        path.reverse()

        self.path = path

    def get_path(self):
        return self.path

    def get_complexity(self):
        return self.no_expanded_nodes

# %%
import math

## A heuristic
def euclidean(a, b):
    return math.sqrt((a[0] - b[0])**2 + (a[1] - b[1])**2)

# Add more heuristics here

### YOUR CODE HERE \/
def manhattan(a,b):
    return abs(a[0] - b[0]) + abs(a[1]-b[1])

def custom(a,b):
    return (euclidean(a,b) + manhattan(a,b)) //2

def custom3d(a,b):
    return ((a[0] - b[0])**2 + (a[1] - b[1])**2)**(0.3)

### YOUR CODE HERE /\

# %% [markdown]
# ## Create a 41x41 maze
# N = 41
# S = (5, 9)
# F = (37, 37)
#
# map = Maze(N, S, F)

# %%
N = 41
S = (5, 9)
F = (37, 37)

map = Maze(N, S, F)

# %% [markdown]
# $g(n)=1$ και $h(n)=0$
#
# Αυτή η περίπτωση μας θυμίζει τον αλγόριθμο του **Dijkstra** καθώς δεν έχουμε ευρετική συνάρτηση και επεκτείνουμε το καλύτερο μονομάτι βάση πραγματικού κόστους. Ο αλγόριθμος αυτός βρίσκει πάντα την βέλτιστη λύση.
# Παρακάτω παρατηρούμε ότι:
# * Για το 41x41 λαβύρινθο  βρίσκουμε λύση στα 0.662s έχοντας επισκεφθεί 730 κόμβους.

# %%
# %%time
## Find and visualize the path
pf = pathfinder(S, F, map, lambda x, y: 1, lambda x, y: 0)
map.draw_map(pf.get_path())
# Out:
# CPU times: user 609 ms, sys: 83 ms, total: 692 ms
# Wall time: 662 ms

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 730

# %% [markdown]
# $g(n)=1$ και $h(n)=\{\text{manhattan}(n),\text{euclidean}(n)\}$
# Σε αυτήν την περίπτωση λοιπόν έχουμε τον αλγόριθμο **A*** ο οποίος χρησιμοποιεί και την πραγματική απόσταση και την τιμή της ευρετικής συνάρτησης για να ταξινομεί τα μονοπάτια. Ο **Α*** βρίσκει πάντα την βέλτιστη λύση εφόσον η ευριστική είναι αποδεκτή. Η απόσταση Manhattan είναι αποδεκτή ευριστική προφανώς αφού πάντα μας δείχνει την ελάχιστη δυνατή απόσταση από έναν κόμβο προς τον κόμβο στόχο. Η ευκλείδια απόσταση είναι πάντα μιρκοτερη της manhattan (τριγωνική ανισότητα) συνεπώς είναι και αυτή αποδεκτή.
# Παρακάτω παρατηρούμε ότι:
# * Για το 41x41 λαβύρινθο  με χρήση ευκλείδιας ευρετικής βρίσκουμε λύση στα 0.606s έχοντας επισκεφθεί 691 κόμβους.
# * Για το 41x41 λαβύρινθο  με χρήση manhattan ευρετικής βρίσκουμε λύση στα 0.543s έχοντας επισκεφθεί 669 κόμβους.
# H ευρετική manhattan είναι σαφώς καλύτερη μιάς και κινούμαστε σε grid.
# * Για το 41x41 λαβύρινθο  με χρήση ευρετικής τον μέσο όρο τον δύο προηγούμενων ευρετικών βρίσκουμε λύση στα 0.525s έχοντας επισκεφθεί 682 κόμβους.

# %%
# %%time
pf = pathfinder(S, F, map, lambda x, y: 1, euclidean)
map.draw_map(pf.get_path())
# Out:
# CPU times: user 537 ms, sys: 86.3 ms, total: 624 ms
# Wall time: 606 ms

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 691

# %%
# %%time
pf = pathfinder(S, F, map, lambda x, y: 1, manhattan)
map.draw_map(pf.get_path())
# Out:
# CPU times: user 514 ms, sys: 53.5 ms, total: 567 ms
# Wall time: 543 ms

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 669

# %%
# %%time
pf = pathfinder(S, F, map, lambda x, y: 1, custom)
map.draw_map(pf.get_path())
# Out:
# CPU times: user 524 ms, sys: 23.1 ms, total: 547 ms
# Wall time: 525 ms

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 682

# %% [markdown]
# $g(n)=0$ και $h(n)=\{\text{manhattan}(n),\text{euclidean}(n)\}$
# Σε αυτήν την περίπτωση λοιπόν έχουμε τον αλγόριθμο **Best-First** ο οποίος αγνοεί την πραγματική απόσταση και ταξινομεί τα μονοπάτια μόνο με βάση την ευρετική συνάρτηση. Δυστυχώς ο **Best-First** δεν μας προσφέρει κάποια εγγύηση για το αν θα βρεθεί το βέλτιστό μονοπάτι ή όχι.
# Παρακάτω παρατηρούμε ότι:
# * Για το 41x41 λαβύρινθο  με χρήση ευκλείδιας ευρετικής βρίσκουμε λύση στα 0.144s έχοντας επισκεφθεί 351 κόμβους.
# * Για το 41x41 λαβύρινθο  με χρήση manhattan ευρετικής βρίσκουμε λύση στα 0.124s έχοντας επισκεφθεί 187 κόμβους.
# H ευρετική manhattan είναι σαφώς καλύτερη μιάς και κινούμαστε σε grid.

# %%
# %%time
pf = pathfinder(S, F, map, lambda x, y: 0, euclidean)
map.draw_map(pf.get_path())
# Out:
# CPU times: user 328 ms, sys: 28.2 ms, total: 356 ms
# Wall time: 349 ms

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 380

# %%
# %%time
pf = pathfinder(S, F, map, lambda x, y: 0,manhattan )
map.draw_map(pf.get_path())
# Out:
# CPU times: user 366 ms, sys: 52.2 ms, total: 418 ms
# Wall time: 368 ms

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 453

# %% [markdown]
# ### Maze 101x101

# %%
N = 101
S = (1, 1)
F = (99, 99)

map = Maze(N, S, F)

# %% [markdown]
# $g(n)=1$ και $h(n)=0$
#
# * Για το 101x101 λαβύρινθο  βρίσκουμε λύση στα 15.3s έχοντας επισκεφθεί 4899 κόμβους.

# %%
# %%time
## Find and visualize the path
pf = pathfinder(S, F, map, lambda x, y: 1, lambda x, y: 0)
map.draw_map(pf.get_path())
# Out:
# CPU times: total: 14.7 s
# Wall time: 15.3 s

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 4899

# %% [markdown]
# $g(n)=0$ και $h(n)=\{\text{manhattan}(n),\text{euclidean}(n)\}$
# Παρακάτω παρατηρούμε ότι:
# * Για το 101x101 λαβύρινθο  με χρήση manhattan ευρετικής βρίσκουμε λύση στα 9.01s έχοντας επισκεφθεί 3265 κόμβους.
# * Για το 101x101 λαβύρινθο  με χρήση  ευκλείδιας ευρετικής βρίσκουμε λύση στα 10.7s έχοντας επισκεφθεί 3524 κόμβους.
# H ευρετική manhattan είναι σαφώς καλύτερη μιάς και κινούμαστε σε grid.

# %%
# %%time
pf = pathfinder(S, F, map, lambda x, y: 1, manhattan)
map.draw_map(pf.get_path())
# Out:
# CPU times: total: 8.38 s
# Wall time: 9.01 s

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 3265

# %%
# %%time
pf = pathfinder(S, F, map, lambda x, y: 1, euclidean)
map.draw_map(pf.get_path())
# Out:
# CPU times: total: 9.53 s
# Wall time: 10.7 s

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 3524

# %% [markdown]
# $g(n)=1$ και $h(n)=\{\text{manhattan}(n),\text{euclidean}(n)\}$
#
# Παρακάτω παρατηρούμε ότι:
# * Για το 101x101 λαβύρινθο  με χρήση ευκλείδιας ευρετικής βρίσκουμε λύση στα 9.2s έχοντας επισκεφθεί 3524 κόμβους.
# * Για το 101x101 λαβύρινθο  με χρήση manhattan ευρετικής βρίσκουμε λύση στα 8.97s έχοντας επισκεφθεί  3265 κόμβους.
# * Για το  λαβύρινθο 101x101 με χρήση ευρετικής τον μέσο όρο τον δύο προηγούμενων ευρετικών βρίσκουμε λύση στα 8.15s έχοντας επισκεφθεί 3358 κόμβους.

# %%
# %%time
pf = pathfinder(S, F, map, lambda x, y: 1, euclidean)
map.draw_map(pf.get_path())
# Out:
# CPU times: total: 8.78 s
# Wall time: 9.2 s

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 3524

# %%
# %%time
pf = pathfinder(S, F, map, lambda x, y: 1, manhattan)
map.draw_map(pf.get_path())
# Out:
# CPU times: total: 8.97 s
# Wall time: 10.3 s

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 3265

# %%
# %%time
pf = pathfinder(S, F, map, lambda x, y: 1, custom)
map.draw_map(pf.get_path())
# Out:
# CPU times: total: 7.92 s
# Wall time: 8.15 s

# %%
expanded_nodes = pf.get_complexity()
print('Number of expanded nodes:', expanded_nodes)
# Out:
# Number of expanded nodes: 3358

# %% [markdown]
# ## Μέρος 3
#
# Στο παρακάτω κελί σάς δίνεται ένα παράδειγμα για την κατασκευή γραφικών παραστάσεων. Θα πρέπει να κατασκευάσετε τις δύο γραφικές παραστάσεις σύμφωνα με τα ζητούμενα της άσκησης.

# %%
path_lengths_a = [1,2,3,4,5,6,7,8,9]
path_lengths_b = [1,1,2,3,5,8,13,21,34]
map_sizes = [10,20,30,40,50,60,70,80,90]

plt.plot(map_sizes, path_lengths_a)
plt.plot(map_sizes, path_lengths_b )
plt.legend(['algorithm A', 'algorithm B'])
plt.title('Path length vs map size')
plt.show()

# %% [markdown]
# Δημιουργούμε χίλιους εκατό πίνακες με Ν = [9, 19, 29 ..., 109]

# %%
### YOUR CODE HERE \/
S = (1, 1)

maps =[]
for i in range(9, 109, 10):  #only
  hundreds = []
  F= (i-2, i-2)
  for j in range(0, 100):
    hundreds.append(Maze(i, S, F))
  maps.append(hundreds)
print(F)
### YOUR CODE HERE /\
# Out:
# (97, 97)

# %% [markdown]
# Εκτυπώνουμε 10 εκδόσεις για Ν = 29 για να σιγουρευτούμε ότι πράγματι για το ίδιο Ν παράγουμε πολλούς διαφορετικούς πίνακες.

# %%
for i in range(0, 10):
  maps[2][i].draw_map()

# %% [markdown]
# Στη συνέχεια εκτυπώνουμε έναν πίνακα από κάθε μέγεθος για να ελέγξουμε ότι το κάναμε σωστά.

# %%
for i in range(0, 10):
  maps[i][1].draw_map()

# %% [markdown]
# Τώρα για κάθε αλγόριθμο και για κάθε Ν θα κάνουμε τις απαιτούμενες μετρήσεις και θα εξάγουμε τον μέσον όρο τους. Στη συνέχεια οι γραφικές μας παραστάσεις θα είναι οι μεσοι όροι ως συνάρτηση του Ν. Η getData επιστρέφει δύο πίνακες, έναν με τους μέσους όρους του πλήθους των ανεπτυγμένων κόμβων (complexities) για κάθε Ν και έναν με τους μέσους όρους των μηκών των βέλτιστων μονοπατιών για κάθε Ν.
#
# Σημείωση: οι μέσοι όροι εξάγονται χρησιμοποιώντας πολλές εκδόσεις λαβυρύνθων για ίδια Ν.

# %%
def getData(maps, maxtests, g, h):
    complexities = []
    path_sizes = []
    for N in range(0, len(maps)):
        tempc = []
        tempp = []
        for i in range(0, maxtests):
            pf=pathfinder(maps[N][i].S, maps[N][i].F, maps[N][i], g, h)
            tempc.append(pf.get_complexity())
            tempp.append(len(pf.get_path()))
        complexities.append(np.average(tempc))
        path_sizes.append(np.average(tempp))
    return (complexities, path_sizes)

# %% [markdown]
# Παρακάτω τρέχουμε την getData για κάθε αλγόριθμο:
#
# Πρώτα για τον **Dijkstra**

# %%
a, b = getData(maps, 100, lambda x,y:1, lambda x,y:0)

# %% [markdown]
# Μετά για τον **Best-First** με ευρετική απόστασης manhattan

# %%
c, d = getData(maps, 100, lambda x,y:0,manhattan)

# %% [markdown]
# Μετά για τον **Best-First** με ευρετική απόστασης ευκλείδια

# %%
e, f = getData(maps, 100, lambda x,y:0, euclidean)

# %% [markdown]
# Έπειτα τρέχουμε τον **A*** με τρεις διαφορετικές ευρετικές: manhattan, euclidean, custom, όπου η custom είναι μία δική μας ευρετική, η οποία αθροίζει την απόσταση manhattan, την ευκλείδια απόσταση και διαιρεί δια δύο υπολογίζοντας ουσιαστικά τον μέσο όρο των δύο αποστάσεων.

# %%
g, h = getData(maps, 100, lambda x,y:1, manhattan)

# %%
i, j = getData(maps, 100, lambda x,y:1, euclidean)

# %%
k, l = getData(maps, 100, lambda x,y:1, custom)6

# %% [markdown]
# Σχεδιάζουμε τις γραφικές παραστάσεις του πλήθους των ανεπτυγμένων κόμβων, δηλαδή της πολυπλοκότητας ως συνάρτηση του Ν για τους 6 αλγορίθμους σε κοινό διάγραμμα.

# %%
map_sizes = [9, 19, 29, 39, 49, 59, 69, 79, 89, 99]

plt.plot(map_sizes, a)
plt.plot(map_sizes, c)
plt.plot(map_sizes, e)
plt.plot(map_sizes, g)
plt.plot(map_sizes, i)
plt.plot(map_sizes, k)
plt.legend(['Dijkstra','Best First(manhattan)','Best First(euclidean)','A*(manhattan)','A*(euclidean)','A*(custom)'])
plt.title('Complexities vs map size')
plt.show()

# %% [markdown]
# Παρατηρούμε ότι η πολυπλοκότητα αυξάνεται με το Ν όπως ήταν αναμενόμενο.
# Περισσότερους κόμβους για κάθε Ν αναπτύσει ο dijkstra καθώς δεν εκμεταλεύεται κάποια ευρετική για να μειώσει τις πιθανές επιλογές σε κάθε βήμα.
# Οι αλγόριθμοι A* είναι καλύτεροι από τον Dijkstra όσον αφορά τους κόμβους που αναπτύσσουν. Συγκεκριμένα, καλύτερος είναι αυτός που χρησιμοποιεί την απόσταση manhattan, δεύτερος είναι αυτός με την δική μας ευρετική και χειρότερος από τους 3 είναι αυτός που χρησιμοποιεί ευκλείδεια απόσταση για ευρετική. Το αποτέλεσμα είναι λογικό καθώς στα grids όπου δεν υπάρχουν διαγώνιες κινήσεις η απόσταση manhattan προσεγγίζει καλύτερα τις πραγματικές αποστάσεις των διαδρομών. Η δική μας ευρετική ως μέσος όρος των άλλων δύο έχει και μέτρια απόδοση.
# Λιγότερους κόμβους απ' ολους τους αλγορίθμους αναπτύσουν οι Best-First και συγκεκριμένα ο Best-First που χρησιμοποιεί ευκλείδεια απόσταση αλλά με τόσο μικρή διαφορά που μπορεί να επηρεάζεται έντονα από την κάθε περίπτωση λαβυρίνθου. Η καλύτερη αυτή πολυπλοκότητα του Best-First σε σχέση με τον Α* και τον Dijkstra ήταν αναμενόμενη καθώς ο Best-First εξετάζει τα μονοπάτια μόνο με βάση τις ευρετικές. Ωστόσο δεν μας εγγυάται ότι θα βρει την καλύτερη λύση.
# Εν τέλει, είναι σημαντικό να παρατηρήσουμε ότι ο Best-First έχει πολυπλοκότητα που είναι περίπου γραμμική ως συνάρτηση του Ν ενώ οι άλλοι αλγόριθμοι είναι πολυωνυμικοί ως συνάρτηση του Ν.
# Ξανα παραθέτουμε την γραφική παράσταση εδώ σε περίπτωση που χαθεί:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Επαναλαμβάνουμε την διαδικασία για τα μήκη των μονοπατιών:

# %%
map_sizes = [9, 19, 29, 39, 49, 59, 69, 79, 89, 99]

plt.plot(map_sizes, b)
plt.plot(map_sizes, d)
plt.plot(map_sizes, f)
plt.plot(map_sizes, h)
plt.plot(map_sizes, j)
plt.plot(map_sizes, l)
plt.legend(['Dijkstra','Best First(manhattan)','Best First(euclidean)','A*(manhattan)','A*(euclidean)','A*(custom)'])
plt.title('Path Lenghts vs map size')
plt.show()

# %% [markdown]
# Τα μήκη των μονοπατιών μεγαλώνουν προφανώς ανάλογα με το Ν,  με σχεδόν γραμμικό τρόπο. Οι διακυμάνσεις που εμφανίζονται οφείλονται στις διαφορές μεταξύ των λαβυρίνθων καθώς ένας μεγάλος λαβύρινθος μπορεί να έχει πολύ μικρότερη βέλτιστη λύση από έναν λίγο μικρότερό του.
# Όπως ήταν αναμενόμενο οι γραφικές παραστάσεις των A* και του Dijkstra ταυτίζονται και έχουν τη μικρότερη κλίση. Αυτό οφείλεται στο γεγονός ότι και οι δύο βρίσκουν βέλτιστες λύσεις και καθώς η βέλτιστη λύση είναι η ίδια για κάθε λαβύρινθο, ο Α* βρίσκει την ίδια λύση με τον Dijksta. Οφείλουμε ωστόσο να σημειώσουμε ότι ο A* δεν βρίσκει την βέλτιστη λύση αν η ευρετική δεν είναι αποδεκτή (αν είναι δηλαδή απαισιόδοξη και υπολογίζει μεγαλύτερα κόστη από τα πραγματικά). Εμείς είμαστε σίγουροι ότι οι ευρετικές μας είναι αισιόδοξες καθώς οι euclidean < manhattan < μονοπάτι με εμπόδια. Το μονοπάτι με τα εμπόδια πάντα θα μεγαλώνει την διαδρομή σε σχέση με αυτή που θα είχαμε αν ηταν κενός χώρος. Τέλος ο Best-First βρίσκει μεγαλύτερα μονοπάτια από τα βέλτιστα ως λύσεις με καλύτερο από τους δύο αυτόν που χρησιμοποιεί ευκλείδεια απόσταση. Η διαφορά αυτή οφείλεται μάλλον στο γεγονός ότι στις συγκεριμένες περιπτώσεις η ευκλείδια έδινε καλύτερες επιλογές κατά την εύρεση μονοπατιού και μπορεί να διέφερε αν είχαμε άλλους λαβυρίνθους.

# %% [markdown]
# Ως χρήστες αυτών των αλγορίθμων οφείλουμε να γνωρίζουμε καλά τις απαιτήσεις μας και τις δυνατότητές μας. Δεν μπορούμε σε όλα τα προβλήματα να εφαρμόζουμε τον ίδιο αλγόριθμο. Όταν για παράδειγμα δεν έχουμε ευρετική προτιμάμε τον Dijkstra. Όταν θέλουμε να κάνουμε οικονομία στην επεξεργαστική μας ισχύ και έχουμε μία αρκετά καλή ευρετική χρησιμοποιούμε Best-First. Όταν θέλουμε εγγύηση ότι ο αλγόριθμός μας θα βρεί την βέλτιστη λύση και έχουμε συγχρόνως αποδεκτή ευρετική χρησιμοποιούμε Α*.
# Ξαναπαραθέτουμε την παραπάνω γραφική παράσταση ώστε να υπάρχει σε περίπτωση που χαθεί:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Μερος 4

# %% [markdown]
# Πρώτα, σας δίνεται αυτούσιος ο κώδικας του φαντάσματος. Το φάντασμα μας κυνηγάει τρέχοντας Α* με στόχο τη θέση μας.

# %%
class Agent:
  def __init__(self,S,grid,color, name = ""):
    self.agent_name = name
    self.location = S
    self.color=color
    self.maze = grid
    self.maze.agents.append(self)
    self.maze.grid[S]=1
    self.path=[]

  def find_path(self,F):
    c = lambda x,y: 1
    h = euclidean
    pf = pathfinder(self.location, F, self.maze, c, h, visualize=False)
    self.path = pf.path


  def move(self):
    if len(self.path)<1:
      return
    if self.location==self.path[0] and len(self.path)>1:
      self.location=self.path[1]
      self.path = self.path[2:]
    else:
      self.location=self.path[0]
      self.path=self.path[1:]

  def move_to(self, loc):
    self.location = loc

# %% [markdown]
# Στη συνέχεια, δίνεται ο κώδικας για τον agent που τρέχει να ξεφύγει. Ο ABagent τρέχει ΑΒ με σκοπό να φτάσει στον τερματισμό χωρίς να τον πιάσει το φάντασμα. Καλείστε να συμπληρώσετε τα σημεία που παραλείπονται. Δώστε ιδιαίτερη προσοχή στην ευριστική συνάρτηση. Εξηγείστε τις επιλογές σας, όπως περιγράφεται παραπάνω.

# %%
class ABagent:
  def __init__(self, S, grid, color, name = ""):
    self.agent_name = name
    self.location = S
    self.color=color
    self.maze = grid
    self.maze.agents.append(self)
    self.maze.grid[S]=1
    self.path=[]

  def get_best_action(self, ghosts, depth = 3,parameter=1):
      best_action = None
      best_score = float("-inf") #you can use this for debugging
      alpha = float("-inf")
      beta = float("inf")

      best_score, best_action = self.alpha_beta_agent(self.maze, self.location, ghosts, depth, alpha, beta, True,parameter)

      return best_action

  def alpha_beta_agent(self, maze, agent_pos, ghost_positions, depth, alpha, beta, maximizing_player=True,parameter=1):
      if depth == 0 or self.is_win(maze, agent_pos) or self.is_lose(agent_pos, ghost_positions):
          # Return the heuristic value if we've reached the maximum depth or the game is over
          return self.heuristic_AB(map, agent_pos, ghost_positions,parameter), agent_pos

      if maximizing_player:
          # Agent is the maximizing player
          best_score = float("-inf")
          best_action = None
          for successor_state in maze.adjacent_no_walls(agent_pos):
              score, _ = self.alpha_beta_agent(maze, successor_state, ghost_positions, depth - 1, alpha, beta, False,parameter)
              if score > best_score:
                  best_score = score
                  best_action = successor_state
              alpha = max(alpha, score)
              if beta <= alpha:
                  break
          return best_score, best_action
      else: 
          # Ghosts are the minimizing players
          ### YOUR CODE HERE \/
        best_score = float("inf")
        best_action = None
        for ghost_position in ghost_positions:
            scores = [float("inf")]
            for successor_state in maze.adjacent_no_walls(ghost_position):
                score_t, _ = self.alpha_beta_agent(maze, successor_state, ghost_positions, depth - 1, alpha, beta, True,parameter)
                scores.append(score_t)
            score = min(scores)
            if score < best_score:
                best_score = score
                best_action = successor_state
            beta = min(beta,score)
            if beta <= alpha:
                break
        return best_score, best_action
          ### YOUR CODE HERE /\


  def is_win(self, maze, agent):
      ### YOUR CODE HERE \/
      return agent == (31,31)
      ### YOUR CODE HERE /\

  def is_lose(self, agent, ghosts):
      ### YOUR CODE HERE \/
        for ghost in ghosts:
            if agent == ghost:
                return True
            else:
                continue
        return False
      ### YOUR CODE HERE /\

  def heuristic_AB(self, map, agent_pos, ghost_positions,parameter=1):
    
      ### YOUR CODE HERE \/
    w1 = []
    h = manhattan
    if parameter == 4 or parameter == 1:
        c = lambda x,y: 0
    else:
        c = lambda x,y: 1
   
    
    for ghost_position in ghost_positions:
        w1.append(manhattan(agent_pos,ghost_position))
    w2 = min(w1)
    if parameter == 3:
        return 0.1*w2-manhattan(agent_pos,map.F)
    
    pf = pathfinder(agent_pos, map.F, map, c, h, visualize=False)
    w = len(pf.get_path())
    if parameter == 1:
        return math.exp(-w)*math.exp(w2)
    elif parameter == 1 or parameter == 4:
        return 1/(w+0.00001)-1/(10*w2+0.00001)
      ### YOUR CODE HERE /\

  def move_to(self, loc):
    self.location = loc

# %% [markdown]
# Παραπάνω βλέπουμε και τις ευριστικές .Σκοπός μας είναι να διαλέγουμε τον κόμβο που είναι πιο κοντά στον τερματισμό αποφεύγωντας και το ghost, συνεπώς θέλουμε μεγάλη τιμή ευριστικής να αντιστοιχεί σε καλό κόμβο.'Αρα επειδή όσο πιο κοντά είμαι στον στόχο τόσο καλύτερα πρέπει αυτήν την μικρή απόσταση να την μεταφράζω σε μια μεγάλη τιμή μεσω μίας γνησιώς φθίνουσας συνάρτησης .όμοια όσο πιο μακριά από το ghost τόσο καλύτερα άρα για αυ΄την την απόσταση θέλουμε μία γνησίως αύξουσα συνάρτηση .
# * Η **3η** είναι και η πιο απλή και γρήγορη καθώς τρέχει στον κόμβο που είναι πιο κοντά στον τερματισμό (αλλά και μακριά από το ghost) . Φυσικά επειδή δεν λαμβανει υπόψην τα εμπόδια μπορεί εύκολα να εγκλωβιστεί. Όσο αραιότερος είναι ο λαβύρινθος τόσο καλύτερα για αυτήν την ευριστική.
# * Η **2η** χρησιμοποιεί τον Α* . Κάνουμε χρήση της manhattan αφού όπως είδαμε και στο μερος 3 λειτουργεί ταχύτερα. Για την απόσταση με τα φαντάσματα χρησιμοποιύμε την manhattan ενώ το φάντασμα μας κυνηγάει με ευκλείδια απόσταση.Επιλέγουμε την συνάρτηση 1/χ προσέχοντας να μην διαιρέσουμε με το 0. Όσο πιο κοντά είναι το ghost τόσο αυξάνεται η επίδραση της απόστασης του ghost στην επόμενη κίνησή μας. Αυτό σημαίνει πώς όταν είναι δίπλα μας το ghost, μπορεί να αγνοούμε αρκετά το στόχο. Για να μειωθεί αυτό το φαινόμενο προσαρμόζουμε κατάλληλα με πολλαπλασιαστικές σταθερές. Βλέπουμε όμως ότι χρειαζόμαστε αρκετό χρόνο οπότε στον επόμενο αλγόριθμο τρέχουμε Best First.
# * H **1η** και η **4η** τρέχουν best first και τρέχουν πολύ πιο γρηγορα ωστόσο μπορεί να μην ακολουθήσουν το καλύτερο δυνατό μονοπάτι. (όπως φαίνεται και από το 3ο μέρος). Στην πρώτη επιλέξαμε να πολλαπλασιάσουμε το ζεύγος των συναρτήσεων και όχι να το προσθέσουμε. Τα αποτελέσματα ήταν αντίστοιχα.

# %% [markdown]
# Φτιάχνουμε αραιό χάρτη και ορίζουμε τους agents.

# %%
#create a sparse map with many paths, like the one below
map = Maze(33, (1,1), (31,31), threshold=0.5)#we choose threshold  to make the maze a little sparse
#map.draw_map()
ghosts=[]

# %%
x, y = np.random.choice(range(7, 31)), np.random.choice(range(7, 31))
ghost = (Agent((x, y), map, [255,30,10], "ghost"))
ghosts.append(ghost)

a1 = ABagent((1,1), map,[30,10,255], "agentAB")

#map.draw_map()

# %% [markdown]
# Παρακάτω, υλοποιείται το κυνηγητό. Ενδεικτικά ορίζουμε την παράμετρο depth του ΑΒ ίση με 5.
#
# Προσοχή: όπως σημειώνεται, μπορούμε να κάνουμε τους παίκτες να τρέχουν με διαφορετικές ταχύτητες. Είναι προτιμητέο να κρατήσετε την ταχύτητα ίση (όπως παρακάτω). Διαφορετικά, θα χρειαστεί να τροποποιήσετε τον αλγόριθμο ΑΒ.
#
# Μετρείστε το χρόνο εκτέλεσης και παρουσιάστε παραδείγματα. Γιατί ο αλγόριθμος σας δουλεύει;

# %%
# %%time
vis=visualization((1,1),(31,31))

visited = [a1.location] #HINT: this might be helpful to you
lose = False

for i in range(100):
  if a1.location==(31,31):
    print("Win")
    break
  for ghost in ghosts:
    if a1.location == ghost.location:
        lose = True
        break
  if lose:
    print("Lose")
    break

  if i%1==0: #controls agent speed
    map_t = copy.deepcopy(map)
    for i in range(min(5,len(visited))):
        map_t.grid[visited[len(visited)-1-i]]=0
    
    
    a2 = ABagent(a1.location, map_t,[30,10,255], "agentAB2")
    best_move_2 = a2.get_best_action([ghost.location], 1,2)
    if best_move_2 == None:
        best_move = a1.get_best_action([ghost.location], 1,2)
    else:
        best_move = best_move_2
    a1.move_to(best_move)
    visited.append(a1.location)
  if i%1==0: #controls ghost speed
    for ghost in ghosts:
        ghost.find_path(a1.location)
        ghost.move()

  im = map.draw_map(return_image=True)
  vis.images.append(im)
# Out:
# Win
# CPU times: total: 8.17 s
# Wall time: 10.6 s

# %% [markdown]
# Παρακάτω βλέπουμε το κυνηγητό με τον Agent να κάνει χρήση της **2ης** ευριστικής αλλά και το depth να είναι ίσο με 1. Αυτό δουλεύει πολύ καλά και γρήγορα καθώς στον ΑΒ δεν δημιουργείται δέντρο και παίζει μόνο ο maximizing player συνεπώς σε κάθε βήμα κάνουμε την καλύτερη δυνατή κίνηση. Παράλληλα αξίζει να σημειωθεί πως ο αλγόριθμος τρέχει και για πολλά φαντάσματα.Η ευριστική σ αυτήν την περίπτωση ασχολείται μόνο με το πιο κοντινό.

# %%
vis.create_gif(fps=1)
vis.show_gif()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5022afd3e9094761bc2ff1d41281f664">
#   <div class="anim-controls">
#     <input id="_anim_slider5022afd3e9094761bc2ff1d41281f664" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5022afd3e9094761bc2ff1d41281f664.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim5022afd3e9094761bc2ff1d41281f664.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim5022afd3e9094761bc2ff1d41281f664.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim5022afd3e9094761bc2ff1d41281f664.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim5022afd3e9094761bc2ff1d41281f664.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim5022afd3e9094761bc2ff1d41281f664.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim5022afd3e9094761bc2ff1d41281f664.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim5022afd3e9094761bc2ff1d41281f664.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim5022afd3e9094761bc2ff1d41281f664.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim5022afd3e9094761bc2ff1d41281f664.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select5022afd3e9094761bc2ff1d41281f664"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5022afd3e9094761bc2ff1d41281f664"
#              >
#       <label for="_anim_radio1_5022afd3e9094761bc2ff1d41281f664">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5022afd3e9094761bc2ff1d41281f664"
#              checked>
#       <label for="_anim_radio2_5022afd3e9094761bc2ff1d41281f664">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5022afd3e9094761bc2ff1d41281f664"
#              >
#       <label for="_anim_radio3_5022afd3e9094761bc2ff1d41281f664">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5022afd3e9094761bc2ff1d41281f664";
#     var slider_id = "_anim_slider5022afd3e9094761bc2ff1d41281f664";
#     var loop_select_id = "_anim_loop_select5022afd3e9094761bc2ff1d41281f664";
#     var frames = new Array(84);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAMA0lEQ

# %% [markdown]
# Εδώ επαναφέρουμε την τιμή του depth στο 5 και τρέχουμε με την **2η** ευρετική

# %%
# %%time
vis=visualization((1,1),(31,31))

visited = [a1.location] #HINT: this might be helpful to you
lose = False

for i in range(100):
  if a1.location==(31,31):
    print("Win")
    break
  for ghost in ghosts:
    if a1.location == ghost.location:
        lose = True
        break
  if lose:
    print("Lose")
    break

  if i%1==0: #controls agent speed
    map_t = copy.deepcopy(map)
    for i in range(min(5,len(visited))):
        map_t.grid[visited[len(visited)-1-i]]=0
    
    
    a2 = ABagent(a1.location, map_t,[30,10,255], "agentAB2")
    best_move_2 = a2.get_best_action([ghost.location], 5,2)
    if best_move_2 == None:
        best_move = a1.get_best_action([ghost.location], 5,2)
    else:
        best_move = best_move_2
    a1.move_to(best_move)
    visited.append(a1.location)

  if i%1==0: #controls ghost speed
    for ghost in ghosts:
        ghost.find_path(a1.location)
        ghost.move()

  im = map.draw_map(return_image=True)
  vis.images.append(im)
# Out:
# CPU times: total: 55 s
# Wall time: 1min 14s

# %% [markdown]
# Εδώ βλέπουμε πως δεν καταφέρνουμε να βρούμε τον στόχο. Αυτό συμβαίνει γιατί τώρα αυξήσαμε το depth άρα παίζει και ο παίκτης min που δεν θα μας δώσει την βέλτιστη δυνατή λύση. Συνεπώς όταν πλησιάσει πολύ το ghost όπως αναφέρθηκε πριν φαίνεται σαν να ξεχνάμε τον στόχο και τρέχουμε να αποφύγουμε το ghost.(τελειώνουν οι επαναλήψεις του for loop οπότε τερματίζει το πρόγραμμα χωρίς να έχουμε νίκη ή ήττα)

# %%
vis.create_gif(fps=1)
vis.show_gif()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img7776e19b917a4c94a8e1a2f54ca41d01">
#   <div class="anim-controls">
#     <input id="_anim_slider7776e19b917a4c94a8e1a2f54ca41d01" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim7776e19b917a4c94a8e1a2f54ca41d01.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim7776e19b917a4c94a8e1a2f54ca41d01.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim7776e19b917a4c94a8e1a2f54ca41d01.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim7776e19b917a4c94a8e1a2f54ca41d01.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim7776e19b917a4c94a8e1a2f54ca41d01.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim7776e19b917a4c94a8e1a2f54ca41d01.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim7776e19b917a4c94a8e1a2f54ca41d01.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim7776e19b917a4c94a8e1a2f54ca41d01.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim7776e19b917a4c94a8e1a2f54ca41d01.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim7776e19b917a4c94a8e1a2f54ca41d01.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select7776e19b917a4c94a8e1a2f54ca41d01"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_7776e19b917a4c94a8e1a2f54ca41d01"
#              >
#       <label for="_anim_radio1_7776e19b917a4c94a8e1a2f54ca41d01">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_7776e19b917a4c94a8e1a2f54ca41d01"
#              checked>
#       <label for="_anim_radio2_7776e19b917a4c94a8e1a2f54ca41d01">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_7776e19b917a4c94a8e1a2f54ca41d01"
#              >
#       <label for="_anim_radio3_7776e19b917a4c94a8e1a2f54ca41d01">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7776e19b917a4c94a8e1a2f54ca41d01";
#     var slider_id = "_anim_slider7776e19b917a4c94a8e1a2f54ca41d01";
#     var loop_select_id = "_anim_loop_select7776e19b917a4c94a8e1a2f54ca41d01";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAL8UlE

# %% [markdown]
# Εδώ έχουμε την **1η** ευριστική

# %%
# %%time
vis=visualization((1,1),(31,31))

visited = [a1.location] #HINT: this might be helpful to you
lose = False

for i in range(100):
  if a1.location==(31,31):
    print("Win")
    break
  for ghost in ghosts:
    if a1.location == ghost.location:
        lose = True
        break
  if lose:
    print("Lose")
    break

  if i%1==0: #controls agent speed
    map_t = copy.deepcopy(map)
    for visited_node in visited:
        map_t.grid[visited_node]=0
    #map_t.grid[visited.pop()]=0
    a2 = ABagent(a1.location, map_t,[30,10,255], "agentAB2")
    best_move_2 = a2.get_best_action([ghost.location], 5,1)
    if best_move_2 == None:
        best_move = a1.get_best_action([ghost.location], 5,1)
    else:
        best_move = best_move_2
    a1.move_to(best_move)
    visited.append(a1.location)

  if i%1==0: #controls ghost speed
    for ghost in ghosts:
        ghost.find_path(a1.location)
        ghost.move()

  im = map.draw_map(return_image=True)
  vis.images.append(im)
# Out:
# Lose
# CPU times: total: 8.48 s
# Wall time: 12.8 s

# %%
vis.create_gif(fps=1)
vis.show_gif()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img828279e5cdfe42bba80a4e020e5ea12b">
#   <div class="anim-controls">
#     <input id="_anim_slider828279e5cdfe42bba80a4e020e5ea12b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim828279e5cdfe42bba80a4e020e5ea12b.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim828279e5cdfe42bba80a4e020e5ea12b.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim828279e5cdfe42bba80a4e020e5ea12b.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim828279e5cdfe42bba80a4e020e5ea12b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim828279e5cdfe42bba80a4e020e5ea12b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim828279e5cdfe42bba80a4e020e5ea12b.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim828279e5cdfe42bba80a4e020e5ea12b.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim828279e5cdfe42bba80a4e020e5ea12b.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim828279e5cdfe42bba80a4e020e5ea12b.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim828279e5cdfe42bba80a4e020e5ea12b.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select828279e5cdfe42bba80a4e020e5ea12b"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_828279e5cdfe42bba80a4e020e5ea12b"
#              >
#       <label for="_anim_radio1_828279e5cdfe42bba80a4e020e5ea12b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_828279e5cdfe42bba80a4e020e5ea12b"
#              checked>
#       <label for="_anim_radio2_828279e5cdfe42bba80a4e020e5ea12b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_828279e5cdfe42bba80a4e020e5ea12b"
#              >
#       <label for="_anim_radio3_828279e5cdfe42bba80a4e020e5ea12b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img828279e5cdfe42bba80a4e020e5ea12b";
#     var slider_id = "_anim_slider828279e5cdfe42bba80a4e020e5ea12b";
#     var loop_select_id = "_anim_loop_select828279e5cdfe42bba80a4e020e5ea12b";
#     var frames = new Array(72);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAL/0lEQ

# %% [markdown]
# Εδώ τρέχουμε με την **3η** ευριστική.

# %%
# %%time
vis=visualization((1,1),(31,31))

visited = [a1.location] #HINT: this might be helpful to you
lose = False

for i in range(100):
  if a1.location==(31,31):
    print("Win")
    break
  for ghost in ghosts:
    if a1.location == ghost.location:
        lose = True
        break
  if lose:
    print("Lose")
    break

  if i%1==0: #controls agent speed
    map_t = copy.deepcopy(map)
    for visited_node in visited:
        map_t.grid[visited_node]=0
    #map_t.grid[visited.pop()]=0
    a2 = ABagent(a1.location, map_t,[30,10,255], "agentAB2")
    best_move_2 = a2.get_best_action([ghost.location], 5,3)
    if best_move_2 == None:
        best_move = a1.get_best_action([ghost.location], 5,3)
    else:
        best_move = best_move_2
    a1.move_to(best_move)
    visited.append(a1.location)

  if i%1==0: #controls ghost speed
    for ghost in ghosts:
        ghost.find_path(a1.location)
        ghost.move()

  im = map.draw_map(return_image=True)
  vis.images.append(im)
# Out:
# Lose
# CPU times: total: 46.9 ms
# Wall time: 118 ms

# %% [markdown]
# Αυτή η ευριστική είναι η πιο γρήγορη. Όμως αγνοεί τους τοίχους για την αξιολόγηση μιας θέσης συνεπώς συνήθως θα μας πιάνει το ghost. Πάλι όταν έχουμε το φάντασμα κοντά μας δίνουμε σ αυτό σημασία.

# %%
vis.create_gif(fps=1)
vis.show_gif()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgeac954775b1046749b8441857efc540d">
#   <div class="anim-controls">
#     <input id="_anim_slidereac954775b1046749b8441857efc540d" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animeac954775b1046749b8441857efc540d.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animeac954775b1046749b8441857efc540d.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animeac954775b1046749b8441857efc540d.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animeac954775b1046749b8441857efc540d.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animeac954775b1046749b8441857efc540d.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animeac954775b1046749b8441857efc540d.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animeac954775b1046749b8441857efc540d.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animeac954775b1046749b8441857efc540d.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animeac954775b1046749b8441857efc540d.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animeac954775b1046749b8441857efc540d.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecteac954775b1046749b8441857efc540d"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_eac954775b1046749b8441857efc540d"
#              >
#       <label for="_anim_radio1_eac954775b1046749b8441857efc540d">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_eac954775b1046749b8441857efc540d"
#              checked>
#       <label for="_anim_radio2_eac954775b1046749b8441857efc540d">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_eac954775b1046749b8441857efc540d"
#              >
#       <label for="_anim_radio3_eac954775b1046749b8441857efc540d">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgeac954775b1046749b8441857efc540d";
#     var slider_id = "_anim_slidereac954775b1046749b8441857efc540d";
#     var loop_select_id = "_anim_loop_selecteac954775b1046749b8441857efc540d";
#     var frames = new Array(72);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAL/0lEQ

# %% [markdown]
# Εδώ βλέπουμε την **4η**

# %%
# %%time
vis=visualization((1,1),(31,31))

visited = [a1.location] #HINT: this might be helpful to you
lose = False

for i in range(100):
  if a1.location==(31,31):
    print("Win")
    break
  for ghost in ghosts:
    if a1.location == ghost.location:
        lose = True
        break
  if lose:
    print("Lose")
    break

  if i%1==0: #controls agent speed
    map_t = copy.deepcopy(map)
    for i in range(min(5,len(visited))):
        map_t.grid[visited[len(visited)-1-i]]=0
    
    
    a2 = ABagent(a1.location, map_t,[30,10,255], "agentAB2")
    best_move_2 = a2.get_best_action([ghost.location], 1,4)
    if best_move_2 == None:
        best_move = a1.get_best_action([ghost.location], 1,4)
    else:
        best_move = best_move_2
    a1.move_to(best_move)
    visited.append(a1.location)
  if i%1==0: #controls ghost speed
    for ghost in ghosts:
        ghost.find_path(a1.location)
        ghost.move()

  im = map.draw_map(return_image=True)
  vis.images.append(im)
# Out:
# Win
# CPU times: total: 906 ms
# Wall time: 1.41 s

# %% [markdown]
# Αυτή η ευριστική μας δίνει πολύ γρήγορα την λύση καθώς εκτελεί Best First που αν και δεν βρίσκει πάντα το βέλτιστό μονοπάτι τρέχει πιο γρήγορα από όλες

# %%
vis.create_gif(fps=1)
vis.show_gif()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9512f2b5bf024a5a8a7b5a431bbed173">
#   <div class="anim-controls">
#     <input id="_anim_slider9512f2b5bf024a5a8a7b5a431bbed173" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9512f2b5bf024a5a8a7b5a431bbed173.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim9512f2b5bf024a5a8a7b5a431bbed173.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim9512f2b5bf024a5a8a7b5a431bbed173.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim9512f2b5bf024a5a8a7b5a431bbed173.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim9512f2b5bf024a5a8a7b5a431bbed173.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim9512f2b5bf024a5a8a7b5a431bbed173.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim9512f2b5bf024a5a8a7b5a431bbed173.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim9512f2b5bf024a5a8a7b5a431bbed173.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim9512f2b5bf024a5a8a7b5a431bbed173.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim9512f2b5bf024a5a8a7b5a431bbed173.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select9512f2b5bf024a5a8a7b5a431bbed173"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9512f2b5bf024a5a8a7b5a431bbed173"
#              >
#       <label for="_anim_radio1_9512f2b5bf024a5a8a7b5a431bbed173">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9512f2b5bf024a5a8a7b5a431bbed173"
#              checked>
#       <label for="_anim_radio2_9512f2b5bf024a5a8a7b5a431bbed173">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9512f2b5bf024a5a8a7b5a431bbed173"
#              >
#       <label for="_anim_radio3_9512f2b5bf024a5a8a7b5a431bbed173">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9512f2b5bf024a5a8a7b5a431bbed173";
#     var slider_id = "_anim_slider9512f2b5bf024a5a8a7b5a431bbed173";
#     var loop_select_id = "_anim_loop_select9512f2b5bf024a5a8a7b5a431bbed173";
#     var frames = new Array(60);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAMCElEQ

# %% [markdown]
# ## Μέρος 5: Bonus
#
# Υπενθυμίζεται ότι το output των κελιών που σχηματίζετε διατηρείται για περιορισμένο χρονικό διάστημα στο notebook, γι αυτό καλείστε να αποθηκεύσετε τη φωτογραφία (το πραγματοποιεί η συνάρτηση draw()) και να τη μεταφέρετε στο ανάλογο markdown.

# %%
from IPython.display import HTML, Image
from google.colab.output import eval_js
from base64 import b64decode
import PIL


canvas_html = """
<canvas width=301 height=301></canvas>
<br>

<button id = "start" style="background-color: #008000">Start</button>
<button id = "end" style="background-color: #800000">End</button>
<button id = "finish">Finish</button>
<script>

var canvas = document.querySelector('canvas')
var ctx = canvas.getContext('2d')

for (var x = 0.5; x < 301; x += 20) {
  ctx.moveTo(x, 0);
  ctx.lineTo(x, 300);
}

for (var y = 0.5; y < 301; y += 20) {
  ctx.moveTo(0, y);
  ctx.lineTo(300, y);
}

ctx.strokeStyle = "#000";
ctx.stroke();

var button = document.getElementById('finish')
var start_button = document.getElementById('start')
var end_button = document.getElementById('end')


start_button.onclick = ()=>{
    ctx.fillStyle="#008000";
  }

end_button.onclick = ()=>{
    ctx.fillStyle="#800000";
  }


var mouse = {x: 0, y: 0}
canvas.addEventListener('mousemove', function(e) {
  mouse.x = e.pageX - this.offsetLeft
  mouse.y = e.pageY - this.offsetTop
})

function getMousePos(canvas, evt) {
        var rect = canvas.getBoundingClientRect();
        return {
          x: evt.x - rect.left,
          y: evt.y - rect.top
        };
      }

function getNearestSquare(position) {
    var x = position.x;
    var y = position.y;

    if (x < 0 || y < 0) return null;
    x = (Math.floor(x / 20) * 20) + 0.5
    y = (Math.floor(y / 20) * 20) + 0.5
    return {x: x, y: y};
}

function containsObject(obj, list) {
    var i;
    for (i = 0; i < list.length; i++) {
        if (list[i].x === obj.x && list[i].y == obj.y) {
            return i;
        }
    }
    return -1;
}

borders = []

canvas.onmousedown = ()=>{
    var pos = getNearestSquare(getMousePos(canvas, mouse));
    if (pos != null) {
        index = containsObject(pos, borders)
        if (index != -1){
            borders.splice(index, 1)
            ctx.clearRect(pos.x + 1, pos.y, 19, 19)
        }
        else{
            ctx.fillRect(pos.x+1,pos.y+1,18,18);
            borders.push(pos)
        }
        ctx.fillStyle="#000000";
    }
}
var data = new Promise(resolve=>{
  button.onclick = ()=>{
    resolve(canvas.toDataURL('image/png'))
  }
})
</script>
"""

def draw(filename='drawing.png'):
  display(HTML(canvas_html))
  data = eval_js("data")
  print (data)
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return len(binary)


draw()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from IPython.display import HTML, Image
# ----> 2 from google.colab.output import eval_js
#       3 from base64 import b64decode
#       4 import PIL
#
# ModuleNotFoundError: No module named 'google'

# %%
def find_points(image_array, pixels):
    points = []
    for grid_i, i in enumerate(range (10, image_array.shape[0]-10, 20)):
        for grid_j, j in enumerate(range (10, image_array.shape[1]-10, 20)):
            if np.array_equal(image_array[i][j], pixels):
                points.append([grid_i+1, grid_j+1])
    return points

def draw_grid(fname='/content/drawing.png'):
    N = 17
    image = PIL.Image.open(fname)
    image_array = np.round(np.array(image)/255)

    start_x, start_y = find_points(image_array, [0,1,0,1])[0]
    end_x, end_y = find_points(image_array, [1, 0, 0, 1])[0]
    walls = find_points(image_array, [0, 0, 0, 1])
    new_grid = Maze(N, (start_x, start_y), (end_x, end_y))

    for i in range(N):
        for j in range(N):
            if [i, j] in walls:
                new_grid.grid[i,j] = 0
            else:
                new_grid.grid[i, j] = 1

    g = new_grid
    g.draw_map()
    return g

g = draw_grid()

# %%
pf = pathfinder(g.S, g.F, g, lambda x, y: 1, lambda x, y: 0)
g.draw_map(pf.get_path())

# %%
pf.vis.show_gif()

# %% [markdown]
# ### 5.1.

# %%
draw(filename='5.1.png')

# %% [markdown]
# #### Εισάγετε εδώ την φωτογραφία όπως αυτή προέκυψε από την εκτέλεση και αλληλεπίδραση με το παραπάνω κελί.
#
#
# #### Εισάγετε εδώ το σχολιασμό σας
#
#
#
# (Υπενθύμιση: για τον Hill Climbing δε χρειάζετει να τρέξετε το χάρτη που σχηματίσατε)

# %% [markdown]
# ### 5.2.

# %%
draw(filename='5.2.png')

# %% [markdown]
# #### Εισάγετε εδώ την φωτογραφία όπως αυτή προέκυψε από την εκτέλεση και αλληλεπίδραση με το παραπάνω κελί.
#
#
# #### Εισάγετε εδώ το σχολιασμό σας

# %%
g = draw_grid()

# %%
pf = pathfinder(g.S, g.F, g, c, h)   # change arguments to choose the appropriate pathfinding algorithm and cost/heuristic (if applicable)
g.draw_map(pf.get_path())

# %%
pf.vis.show_gif()

# %% [markdown]
# ### 5.3.

# %%
draw(filename='5.3.png')

# %% [markdown]
# #### Εισάγετε εδώ την φωτογραφία όπως αυτή προέκυψε από την εκτέλεση και αλληλεπίδραση με το παραπάνω κελί.
#
#
# #### Εισάγετε εδώ το σχολιασμό σας

# %%
g = draw_grid()

# %%
pf = pathfinder(g.S, g.F, g, c, h)   # change arguments to choose the appropriate pathfinding algorithm and cost/heuristic (if applicable)
g.draw_map(pf.get_path())

# %%
pf.vis.show_gif()

# %% [markdown]
# ### 5.4.

# %%
draw(filename='5.4.png')

# %% [markdown]
# #### Εισάγετε εδώ την φωτογραφία όπως αυτή προέκυψε από την εκτέλεση και αλληλεπίδραση με το παραπάνω κελί.
#
#
# #### Εισάγετε εδώ το σχολιασμό σας

# %%
g = draw_grid()

# %%
pf = pathfinder(g.S, g.F, g, c, h)   # change arguments to choose the appropriate pathfinding algorithm and cost/heuristic (if applicable)
g.draw_map(pf.get_path())

# %%
pf.vis.show_gif()

# %% [markdown]
# ### 5.5

# %%
draw(filename='5.5.png')

# %% [markdown]
# #### Εισάγετε εδώ την φωτογραφία όπως αυτή προέκυψε από την εκτέλεση και αλληλεπίδραση με το παραπάνω κελί.
#
#
# #### Εισάγετε εδώ το σχολιασμό σας

# %%
g = draw_grid()

# %%
pf = pathfinder(g.S, g.F, g, c, h)   # change arguments to choose the appropriate pathfinding algorithm and cost/heuristic (if applicable)
g.draw_map(pf.get_path())

# %%
pf.vis.show_gif()
